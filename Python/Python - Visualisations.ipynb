# %%
import pyodbc
import sqlalchemy as db
from sqlalchemy import create_engine
from sqlalchemy.engine import URL
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import urllib

# %%
def create_params():
    """
    Sets database parameters
    return: params - the database parameters formatted in a string for use with SQLAlchemy
    """
    #Define connection parameters
    driver = "{SQL Server}"
    server = "LAPTOP-UKCTMMGM"
    database_ref = "Premier_League"
    schema = database_ref + ".dbo"
    Trusted_Connection = "Yes" 
    #username = input("Please input SQL Server username") #not needed for my instance
    #password = input("Please input SQL Server password")#not needed for my instance
    params = 'DRIVER='+driver + ';SERVER='+server + ';PORT=1433;DATABASE=' + database_ref + ';Trusted_Connection' + Trusted_Connection 
    return params

# %%
def scatter_plot(title, table, x_value, y_value, point_color, x_label, y_label):
    """
    Returns a Scatter Plot
    """
    plt.plot(constrained_layout = True)
    plt.title(title, fontweight='bold')
    plt.scatter(table[x_value], table[y_value], color = point_color)
    plt.xlabel(x_label, fontweight='bold')
    plt.ylabel(y_label, fontweight='bold')
    plt.show()

# %%
def line_plot(table, x_values, y_values, x_label, y_label, line_colour):
    """
    Returns a line plot
    """
    fig,ax = plt.subplots()
    
    # make a plot
    ax.plot(table[x_values], 
            table[y_values],
            color=line_colour, 
            marker="o")
    for index in range(len(table[x_values])):
      ax.text(table[x_values][index],\
        table[y_values][index] + .2, table[y_values][index], size=12)

    # set x-axis label
    ax.set_xlabel(x_label, fontsize = 14, fontweight='bold')

    # set y-axis label
    ax.set_ylabel(y_label,
                  fontsize=14, fontweight='bold')

    plt.show()

# %% [markdown]
# #### Creating a connection to Database

# %%
# add db parameters to variable
params = create_params()
db_params = urllib.parse.quote_plus(params)

#Create connection to DWH
my_engine = db.create_engine("mssql+pyodbc:///?odbc_connect={}".format(db_params))
my_connection = my_engine.connect()
metadata =  db.MetaData()

# %% [markdown]
# #### Visualising the Data

# %% [markdown]
# #### How many yellows and fouls are given in PL games?

# %%
# 1. How many fouls and yellows are given in PL games?
# 1.1 Get the data from SQL.
fouls_table = pd.read_sql_query("SELECT * FROM Premier_League..fouls_17_22", con=my_connection)
total_fouls = fouls_table['total_fouls']
total_yellows = fouls_table['total_yellows']

# 1.2 plot the distibution
plt.style.use('ggplot')
fig1, ((ax1, ax2)) = plt.subplots(2,1, constrained_layout = True)

ax1.title.set_text('Distribution of Fouls in PL Games')
fouls_dist_bar = ax1.hist(total_fouls, edgecolor = 'black', color = 'teal')
ax1.set_xlabel('Fouls', fontweight='bold')
ax1.set_ylabel('Volume', fontweight='bold')
 

ax2.hist(total_yellows, edgecolor = 'black', color = 'yellow')
ax2.title.set_text('Distribution of Yellows in PL Games')
ax2.set_xlabel('Yellows', fontweight='bold')
ax2.set_ylabel('Volume', fontweight='bold')

plt.show()

# Print the actual means so I can see the averages
print(f"Mean fouls in PL games: {total_fouls.mean().__round__(2)}")
print(f"Mean yellow cards in PL games: {total_yellows.mean().__round__(2)}")

# ANSWER: Games in the Premier League on average have about 25 fouls. 
# There are most often (mode) between 4 and 5 yellow cards but the average amount of yellows is about 3.
# Out:
# Mean fouls in PL games: 24.75
# Mean yellow cards in PL games: 3.33

# %% [markdown]
# #### Has the amount of fouls given away by season changed?

# %%
fouls_by_season = pd.read_sql_query("SELECT * FROM Premier_League..vw_PL_fouls_by_season",
                                                 con=my_connection)
                                                 
fouls_by_season.sort_values(by= "season_end_year", inplace = True) #sorting values for the plot

line_plot(table = fouls_by_season, x_values = "season_end_year", y_values = "average_fouls", x_label = "Years"\
          ,y_label = "Amount of Fouls", line_colour = "teal")

# %% [markdown]
# #### What is the correlation to a teams final statistics vs the total amount of fouls committed in a season?

# %%
# 2. TO DO Can also see if there is correlation to total points and fouls in a season?

fouls_to_standings = pd.read_sql_query("SELECT * FROM Premier_League..vw_correlation_fouls_standings",
                                                 con=my_connection)

fouls_standings_correlation = fouls_to_standings.drop(columns = 'season_end_year').corr(numeric_only = True)

fouls_standings_correlation.style.background_gradient(cmap = 'Greys_r')

# Interestingly total fouls are more negatively correlated to a bad performing team. See wins and total fouls has a 
# correlation matrix of -0.548
# Out:
# <style type="text/css">
# #T_ee18e_row0_col0, #T_ee18e_row1_col1, #T_ee18e_row2_col2, #T_ee18e_row2_col6, #T_ee18e_row3_col3, #T_ee18e_row4_col4, #T_ee18e_row5_col5, #T_ee18e_row6_col2, #T_ee18e_row6_col6, #T_ee18e_row7_col7 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_ee18e_row0_col1 {
#   background-color: #bababa;
#   color: #000000;
# }
# #T_ee18e_row0_col2 {
#   background-color: #444444;
#   color: #f1f1f1;
# }
# #T_ee18e_row0_col3 {
#   background-color: #434343;
#   color: #f1f1f1;
# }
# #T_ee18e_row0_col4, #T_ee18e_row0_col6 {
#   background-color: #383838;
#   color: #f1f1f1;
# }
# #T_ee18e_row0_col5 {
#   background-color: #cecece;
#   color: #000000;
# }
# #T_ee18e_row0_col7 {
#   background-color: #d3d3d3;
#   color: #000000;
# }
# #T_ee18e_row1_col0, #T_ee18e_row7_col0 {
#   background-color: #c3c3c3;
#   color: #000000;
# }
# #T_ee18e_row1_col2, #T_ee18e_row1_col4 {
#   background-color: #5c5c5c;
#   color: #f1f1f1;
# }
# #T_ee18e_row1_col3 {
#   background-color: #585858;
#   color: #f1f1f1;
# }
# #T_ee18e_row1_col5 {
#   background-color: #cdcdcd;
#   color: #000000;
# }
# #T_ee18e_row1_col6 {
#   background-color: #545454;
#   color: #f1f1f1;
# }
# #T_ee18e_row1_col7 {
#   background-color: #c5c5c5;
#   color: #000000;
# }
# #T_ee18e_row2_col0 {
#   background-color: #020202;
#   color: #f1f1f1;
# }
# #T_ee18e_row2_col1, #T_ee18e_row3_col7 {
#   background-color: #010101;
#   color: #f1f1f1;
# }
# #T_ee18e_row2_col3, #T_ee18e_row3_col2 {
#   background-color: #fefefe;
#   color: #000000;
# }
# #T_ee18e_row2_col4, #T_ee18e_row4_col2, #T_ee18e_row4_col6, #T_ee18e_row6_col4 {
#   background-color: #fbfbfb;
#   color: #000000;
# }
# #T_ee18e_row2_col5 {
#   background-color: #060606;
#   color: #f1f1f1;
# }
# #T_ee18e_row2_col7, #T_ee18e_row3_col1, #T_ee18e_row3_col5, #T_ee18e_row6_col0, #T_ee18e_row6_col1, #T_ee18e_row7_col2, #T_ee18e_row7_col3, #T_ee18e_row7_col4, #T_ee18e_row7_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_ee18e_row3_col0, #T_ee18e_row4_col0, #T_ee18e_row5_col3 {
#   background-color: #030303;
#   color: #f1f1f1;
# }
# #T_ee18e_row3_col4, #T_ee18e_row3_col6, #T_ee18e_row4_col3 {
#   background-color: #fcfcfc;
#   color: #000000;
# }
# #T_ee18e_row4_col1 {
#   background-color: #0e0e0e;
#   color: #f1f1f1;
# }
# #T_ee18e_row4_col5 {
#   background-color: #1c1c1c;
#   color: #f1f1f1;
# }
# #T_ee18e_row4_col7 {
#   background-color: #0d0d0d;
#   color: #f1f1f1;
# }
# #T_ee18e_row5_col0 {
#   background-color: #bebebe;
#   color: #000000;
# }
# #T_ee18e_row5_col1 {
#   background-color: #b2b2b2;
#   color: #000000;
# }
# #T_ee18e_row5_col2, #T_ee18e_row6_col5 {
#   background-color: #0c0c0c;
#   color: #f1f1f1;
# }
# #T_ee18e_row5_col4 {
#   background-color: #151515;
#   color: #f1f1f1;
# }
# #T_ee18e_row5_col6, #T_ee18e_row6_col7 {
#   background-color: #080808;
#   color: #f1f1f1;
# }
# #T_ee18e_row5_col7, #T_ee18e_row7_col5 {
#   background-color: #f7f7f7;
#   color: #000000;
# }
# #T_ee18e_row6_col3 {
#   background-color: #fdfdfd;
#   color: #000000;
# }
# #T_ee18e_row7_col1 {
#   background-color: #9e9e9e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ee18e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee18e_level0_col0" class="col_heading level0 col0" >total_fouls</th>
#       <th id="T_ee18e_level0_col1" class="col_heading level0 col1" >total_yellows</th>
#       <th id="T_ee18e_level0_col2" class="col_heading level0 col2" >points</th>
#       <th id="T_ee18e_level0_col3" class="col_heading level0 col3" >goal_difference</th>
#       <th id="T_ee18e_level0_col4" class="col_heading level0 col4" >goals_for</th>
#       <th id="T_ee18e_level0_col5" class="col_heading level0 col5" >goals_against</th>
#       <th id="T_ee18e_level0_col6" class="col_heading level0 col6" >wins</th>
#       <th id="T_ee18e_level0_col7" class="col_heading level0 col7" >losses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee18e_level0_row0" class="row_heading level0 row0" >total_fouls</th>
#       <td id="T_ee18e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ee18e_row0_col1" class="data row0 col1" >0.460583</td>
#       <td id="T_ee18e_row0_col2" class="data row0 col2" >-0.532952</td>
#       <td id="T_ee18e_row0_col3" class="data row0 col3" >-0.524328</td>
#       <td id="T_ee18e_row0_col4" class="data row0 col4" >-0.529143</td>
#       <td id="T_ee18e_row0_col5" class="data row0 col5" >0.430542</td>
#       <td id="T_ee18e_row0_col6" class="data row0 col6" >-0.547888</td>
#       <td id="T_ee18e_row0_col7" class="data row0 col7" >0.455896</td>
#     </tr>
#     <tr>
#       <th id="T_ee18e_level0_row1" class="row_heading level0 row1" >total_yellows</th>
#       <td id="T_ee18e_row1_col0" class="data row1 col0" >0.460583</td>
#       <td id="T_ee18e_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ee18e_row1_col2" class="data row1 col2" >-0.386287</td>
#       <td id="T_ee18e_row1_col3" class="data row1 col3" >-0.395568</td>
#       <td id="T_ee18e_row1_col4" class="data row1 col4" >-0.326694</td>
#       <td id="T_ee18e_row1_col5" class="data row1 col5" >0.424665</td>
#       <td id="T_ee18e_row1_col6" class="data row1 col6" >-0.393016</td>
#       <td id="T_ee18e_row1_col7" class="data row1 col7" >0.339588</td>
#     </tr>
#     <tr>
#       <th id="T_ee18e_level0_row2" class="row_heading level0 row2" >points</th>
#       <td id="T_ee18e_row2_col0" class="data row2 col0" >-0.532952</td>
#       <td id="T_ee18e_row2_col1" class="data row2 col1" >-0.386287</td>
#       <td id="T_ee18e_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_ee18e_row2_col3" class="data row2 col3" >0.972822</td>
#       <td id="T_ee18e_row2_col4" class="data row2 col4" >0.934071</td>
#       <td id="T_ee18e_row2_col5" class="data row2 col5" >-0.864485</td>
#       <td id="T_ee18e_row2_col6" class="data row2 col6" >0.988836</td>
#       <td id="T_ee18e_row2_col7" class="data row2 col7" >-0.942965</td>
#     </tr>
#     <tr>
#       <th id="T_ee18e_level0_row3" class="row_heading level0 row3" >goal_difference</th>
#       <td id="T_ee18e_row3_col0" class="data row3 col0" >-0.524328</td>
#       <td id="T_ee18e_row3_col1" class="data row3 col1" >-0.395568</td>
#       <td id="T_ee18e_row3_col2" class="data row3 col2" >0.972822</td>
#       <td id="T_ee18e_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_ee18e_row3_col4" class="data row3 col4" >0.949944</td>
#       <td id="T_ee18e_row3_col5" class="data row3 col5" >-0.902713</td>
#       <td id="T_ee18e_row3_col6" class="data row3 col6" >0.955807</td>
#       <td id="T_ee18e_row3_col7" class="data row3 col7" >-0.931089</td>
#     </tr>
#     <tr>
#       <th id="T_ee18e_level0_row4" class="row_heading level0 row4" >goals_for</th>
#       <td id="T_ee18e_row4_col0" class="data row4 col0" >-0.529143</td>
#       <td id="T_ee18e_row4_col1" class="data row4 col1" >-0.326694</td>
#       <td id="T_ee18e_row4_col2" class="data row4 col2" >0.934071</td>
#       <td id="T_ee18e_row4_col3" class="data row4 col3" >0.949944</td>
#       <td id="T_ee18e_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_ee18e_row4_col5" class="data row4 col5" >-0.723110</td>
#       <td id="T_ee18e_row4_col6" class="data row4 col6" >0.933846</td>
#       <td id="T_ee18e_row4_col7" class="data row4 col7" >-0.858003</td>
#     </tr>
#     <tr>
#       <th id="T_ee18e_level0_row5" class="row_heading level0 row5" >goals_against</th>
#       <td id="T_ee18e_row5_col0" class="data row5 col0" >0.430542</td>
#       <td id="T_ee18e_row5_col1" class="data row5 col1" >0.424665</td>
#       <td id="T_ee18e_row5_col2" class="data row5 col2" >-0.864485</td>
#       <td id="T_ee18e_row5_col3" class="data row5 col3" >-0.902713</td>
#       <td id="T_ee18e_row5_col4" class="data row5 col4" >-0.723110</td>
#       <td id="T_ee18e_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_ee18e_row5_col6" class="data row5 col6" >-0.827175</td>
#       <td id="T_ee18e_row5_col7" class="data row5 col7" >0.876972</td>
#     </tr>
#     <tr>
#       <th id="T_ee18e_level0_row6" class="row_heading level0 row6" >wins</th>
#       <td id="T_ee18e_row6_col0" class="data row6 col0" >-0.547888</td>
#       <td id="T_ee18e_row6_col1" class="data row6 col1" >-0.393016</td>
#       <td id="T

# %% [markdown]
# #### Lets see the correlation of total foul count to amount of wins in the PL.

# %%
scatter_plot(title = "Foul Count X Wins", table = fouls_to_standings, x_value = "total_fouls", y_value = "wins" \
             , x_label = "Fouls", y_label = "Wins", point_color = "teal" )

# %% [markdown]
# #### Display the referees who give away the most fouls and yellow cards in PL games.

# %%
# Which referee gives away the most fouls?
referree_most_fouls = pd.read_sql_query("SELECT * FROM Premier_League..vw_PL_referee_most_fouls",
                                                 con=my_connection)

referees_highest_fouls = referree_most_fouls.sort_values(by = 'average_fouls', ascending= False).head(5).sort_values(by = 'average_fouls', ascending= True)
referees_highest_yellows = referree_most_fouls.sort_values(by = 'average_yellows', ascending= False).head(5).sort_values(by = 'average_yellows', ascending= True)

# creating a bar chart
fig, (ax1, ax2) = plt.subplots(2,1)
fig.set_figwidth(6)
fig.set_figheight(8)

ax1.set_title('Referee Highest Avg Fouls & Yellows')
fouls_bar = ax1.barh(referees_highest_fouls['referee'], referees_highest_fouls['average_fouls'], edgecolor = 'black', color = 'blue')
ax1.set_ylabel('Referee', fontweight='bold')
ax1.set_xlabel('Average Fouls', fontweight='bold')
ax1.bar_label(fouls_bar)

yellow_bar = ax2.barh(referees_highest_yellows['referee'], referees_highest_yellows['average_yellows'], edgecolor = 'black', color = 'yellow')
ax2.set_ylabel('Referee', fontweight='bold')
ax2.set_xlabel('Average Yellows', fontweight='bold')
ax2.bar_label(yellow_bar)


plt.show()

# %% [markdown]
# #### Which team gives away the most/least fouls per game?

# %%
team_most_fouls = pd.read_sql_query("SELECT *\
                                     FROM Premier_League..vw_PL_team_fouls_yellow_per_game \
                                     ORDER BY average_fouls DESC"
                                                 , con=my_connection)

team_most_fouls.style.background_gradient(cmap = "Greys")
# From the table we can see Fulham, Leeds and Sheffield give away the most fouls on average of all of the teams.
# Bournemouth, Man City and Liverpool give away the least.
# Out:
# <style type="text/css">
# #T_3ef6a_row0_col1, #T_3ef6a_row1_col1, #T_3ef6a_row2_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_3ef6a_row3_col1, #T_3ef6a_row4_col1, #T_3ef6a_row5_col1, #T_3ef6a_row6_col1, #T_3ef6a_row7_col1, #T_3ef6a_row8_col1, #T_3ef6a_row9_col1, #T_3ef6a_row10_col1 {
#   background-color: #515151;
#   color: #f1f1f1;
# }
# #T_3ef6a_row11_col1, #T_3ef6a_row12_col1, #T_3ef6a_row13_col1, #T_3ef6a_row14_col1, #T_3ef6a_row15_col1, #T_3ef6a_row16_col1, #T_3ef6a_row17_col1, #T_3ef6a_row18_col1, #T_3ef6a_row19_col1 {
#   background-color: #959595;
#   color: #f1f1f1;
# }
# #T_3ef6a_row20_col1, #T_3ef6a_row21_col1, #T_3ef6a_row22_col1, #T_3ef6a_row23_col1, #T_3ef6a_row24_col1 {
#   background-color: #d9d9d9;
#   color: #000000;
# }
# #T_3ef6a_row25_col1, #T_3ef6a_row26_col1, #T_3ef6a_row27_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# </style>
# <table id="T_3ef6a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ef6a_level0_col0" class="col_heading level0 col0" >team</th>
#       <th id="T_3ef6a_level0_col1" class="col_heading level0 col1" >average_fouls</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ef6a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3ef6a_row0_col0" class="data row0 col0" >Fulham</td>
#       <td id="T_3ef6a_row0_col1" class="data row0 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3ef6a_row1_col0" class="data row1 col0" >Leeds United</td>
#       <td id="T_3ef6a_row1_col1" class="data row1 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3ef6a_row2_col0" class="data row2 col0" >Sheffield United</td>
#       <td id="T_3ef6a_row2_col1" class="data row2 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3ef6a_row3_col0" class="data row3 col0" >Southampton</td>
#       <td id="T_3ef6a_row3_col1" class="data row3 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3ef6a_row4_col0" class="data row4 col0" >Stoke City</td>
#       <td id="T_3ef6a_row4_col1" class="data row4 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3ef6a_row5_col0" class="data row5 col0" >Manchester United</td>
#       <td id="T_3ef6a_row5_col1" class="data row5 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3ef6a_row6_col0" class="data row6 col0" >Watford</td>
#       <td id="T_3ef6a_row6_col1" class="data row6 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3ef6a_row7_col0" class="data row7 col0" >West Bromwich Albion</td>
#       <td id="T_3ef6a_row7_col1" class="data row7 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3ef6a_row8_col0" class="data row8 col0" >Everton</td>
#       <td id="T_3ef6a_row8_col1" class="data row8 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3ef6a_row9_col0" class="data row9 col0" >Aston Villa</td>
#       <td id="T_3ef6a_row9_col1" class="data row9 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3ef6a_row10_col0" class="data row10 col0" >Brighton & Hove Albion</td>
#       <td id="T_3ef6a_row10_col1" class="data row10 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3ef6a_row11_col0" class="data row11 col0" >Burnley</td>
#       <td id="T_3ef6a_row11_col1" class="data row11 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3ef6a_row12_col0" class="data row12 col0" >Cardiff City</td>
#       <td id="T_3ef6a_row12_col1" class="data row12 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3ef6a_row13_col0" class="data row13 col0" >Crystal Palace</td>
#       <td id="T_3ef6a_row13_col1" class="data row13 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3ef6a_row14_col0" class="data row14 col0" >Huddersfield Town</td>
#       <td id="T_3ef6a_row14_col1" class="data row14 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3ef6a_row15_col0" class="data row15 col0" >Leicester City</td>
#       <td id="T_3ef6a_row15_col1" class="data row15 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3ef6a_row16_col0" class="data row16 col0" >Newcastle United</td>
#       <td id="T_3ef6a_row16_col1" class="data row16 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3ef6a_row17_col0" class="data row17 col0" >Norwich City</td>
#       <td id="T_3ef6a_row17_col1" class="data row17 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3ef6a_row18_col0" class="data row18 col0" >Tottenham Hotspur</td>
#       <td id="T_3ef6a_row18_col1" class="data row18 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3ef6a_row19_col0" class="data row19 col0" >Wolverhampton Wanderers</td>
#       <td id="T_3ef6a_row19_col1" class="data row19 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_3ef6a_row20_col0" class="data row20 col0" >West Ham United</td>
#       <td id="T_3ef6a_row20_col1" class="data row20 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_3ef6a_row21_col0" class="data row21 col0" >Swansea City</td>
#       <td id="T_3ef6a_row21_col1" class="data row21 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_3ef6a_row22_col0" class="data row22 col0" >Chelsea</td>
#       <td id="T_3ef6a_row22_col1" class="data row22 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_3ef6a_row23_col0" class="data row23 col0" >Arsenal</td>
#       <td id="T_3ef6a_row23_col1" class="data row23 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_3ef6a_row24_col0" class="data row24 col0" >Brentford</td>
#       <td id="T_3ef6a_row24_col1" class="data row24 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_3ef6a_row25_col0" class="data row25 col0" >Bournemouth</td>
#       <td id="T_3ef6a_row25_col1" class="data row25 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_3ef6a_row26_col0" class="data row26 col0" >Liverpool</td>
#       <td id="T_3ef6a_row26_col1" class="data row26 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_3ef6a_row27_col0" class="data row27 col0" >Manchester City</td>
#       <td id="T_3ef6a_row27_col1" class="data row27 col1" >10</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Which team do specific referees give the highest % of yellow cards for fouls committed?

# %%
referree_most_hated_team = pd.read_sql_query("SELECT TOP 10 * \
                                              FROM Premier_League..referee_most_hated_team \
                                              ORDER BY yellow_percent DESC",
                                                 con=my_connection)

referree_most_hated_team.sort_values('yellow_percent', inplace = True, ascending = True)

fig, ax = plt.subplots()
hbar = ax.barh(referree_most_hated_team["referee_and_team"], referree_most_hated_team["yellow_percent"],\
    color = "yellow", edgecolor = "black")

ax.set_xlabel("Yellow Cards to Fouls Committed", fontweight='bold')
ax.set_ylabel("Referee and Receiving Team", fontweight='bold')

ax.bar_label(hbar)
plt.show()

# Of all referees and teams Roger East gives the highest ratio of yellow cards to total fouls to Wolves.
# More than 1/3 of fouls Wolves commit when being referee'd by Roger East result in a yellow card!

# %% [markdown]
# #### Does having a referee who gives more yellows cards for fouls committed affect the likelihood of a team winning?

# %%
yellow_ratio_match_results = pd.read_sql_query("SELECT * FROM [Premier_League].[dbo].[referee_yellows_to_wins]",
                                                 con=my_connection)

points_by_referee = yellow_ratio_match_results.groupby(by = ["team", "referee"])\
                                              .agg({"yellow_percent" : "mean", "match_points" : "mean"})\
                                              .rename(columns={"match_points":"average_points"})

points_by_referee.corr()
# Out:
#                 yellow_percent  average_points
# yellow_percent        1.000000       -0.105889
# average_points       -0.105889        1.000000

# %%
scatter_plot(title = "Match Points X Yellow to Fouls Ratio", table = points_by_referee, x_value = "yellow_percent" \
             ,y_value = "average_points" , x_label = "% of Yellow Cards to Fouls", y_label = "Total Points", point_color = "purple"	)

# There is a slight negative correlation evident from the scatter plot and the correlation figure is refelective of this.

# %% [markdown]
# #### How does team performance change playing at home vs away?

# %%
points_by_location = yellow_ratio_match_results.groupby(by = ["home_or_away"])\
                                              .agg({"match_points" : "mean"})\
                                              .round(2)\
                                              .rename(columns={"match_points":"total_points"})
points_by_location

# Teams only receive an average of 0.29 points more per game while playing at home vs away.
# Out:
#               total_points
# home_or_away
# Away                  1.30
# Home                  1.59

# %% [markdown]
# #### Linear regression on the relationship of match points and yellow:fouls ratio.
